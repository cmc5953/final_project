# %%
import sys
# !{sys.executable} -m pip install spotipy

# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd 
import math
import warnings
warnings.simplefilter("ignore")

# %%
sp = spotipy.Spotify()

USER_ID = "emilyrlandman"
TOP10_PLAYLIST_ID = "1ggWDL88pSeijtf7zifvF1"
ALBUMS_PLAYLIST_ID = "5YVVRDq8QLSB2wJ2lvq3Dx"
CLIENT_ID = "27a2df6fdb064b40b952dbe55f451421" 
CLIENT_SECRET = "a97bf4bf619b4239961eb80513e2c0e0" 
CLIENT_CREDENTIALS = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET) 

sp = spotipy.Spotify(client_credentials_manager=CLIENT_CREDENTIALS) 
sp.trace=False

# %%
# First we have to gather the total number of tracks in the playlist 
track_count = sp.user_playlist_tracks(USER_ID, TOP10_PLAYLIST_ID, 'total')['total']

# Then we calculate the number of times we'll have to call the API
iterations = math.ceil(track_count/100)

# Finally we begin our loop
attributes_df = pd.DataFrame()
information_df = pd.DataFrame()
for i in range(iterations):
    playlist = sp.user_playlist_tracks(USER_ID, TOP10_PLAYLIST_ID, None, None, i*100) # documentation - https://spotipy.readthedocs.io/en/2.13.0/
    songs = playlist["items"]
#     time.sleep(1) # incase this is necessary on larger playlists

    track_ids = []
    artist = []
    artist_id = []
    explicit = []
    track = []
    pop = []
    for j in range(len(songs)): 
        track_ids.append(songs[j]["track"]["id"])
        artist.append(songs[j]["track"]["artists"][0]["name"])
        artist_id.append(songs[j]["track"]["artists"][0]["id"])
        explicit.append(songs[j]["track"]["explicit"])
        track.append(songs[j]["track"]["name"])
        pop.append(songs[j]["track"]["popularity"])
    features = sp.audio_features(track_ids)
    att_df = pd.DataFrame(features)
    info_df = pd.DataFrame({"song_id":track_ids, "song_name":track, "artist_id":artist_id, "artist": artist, "explicit":explicit, "popularity":pop})
    attributes_df = attributes_df.append(att_df, ignore_index=True)
    information_df = information_df.append(info_df, ignore_index=True)

TOP_df = information_df.merge(attributes_df, left_on="song_id", right_on="id")
TOP_df["top_10"] = 1
# TOP_df

# %%
# First we have to gather the total number of tracks in the playlist 
track_count = sp.user_playlist_tracks(USER_ID, ALBUMS_PLAYLIST_ID, 'total')['total']

# Then we calculate the number of times we'll have to call the API
iterations = math.ceil(track_count/100)

# Finally we begin our loop
attributes_df = pd.DataFrame()
information_df = pd.DataFrame()
for i in range(iterations):
    playlist = sp.user_playlist_tracks(USER_ID, ALBUMS_PLAYLIST_ID, None, None, i*100) # documentation - https://spotipy.readthedocs.io/en/2.13.0/
    songs = playlist["items"]
#     time.sleep(1) # incase this is necessary on larger playlists

    track_ids = []
    artist = []
    artist_id = []
    explicit = []
    track = []
    pop = []
    for j in range(len(songs)): 
        track_ids.append(songs[j]["track"]["id"])
        artist.append(songs[j]["track"]["artists"][0]["name"])
        artist_id.append(songs[j]["track"]["artists"][0]["id"])
        explicit.append(songs[j]["track"]["explicit"])
        track.append(songs[j]["track"]["name"])
        pop.append(songs[j]["track"]["popularity"])
    features = sp.audio_features(track_ids)
    att_df = pd.DataFrame(features)
    info_df = pd.DataFrame({"song_id":track_ids, "song_name":track, "artist_id":artist_id, "artist": artist, "explicit":explicit, "popularity":pop})
    attributes_df = attributes_df.append(att_df, ignore_index=True)
    information_df = information_df.append(info_df, ignore_index=True)

ALBUMS_df = information_df.merge(attributes_df, left_on="song_id", right_on="id")
ALBUMS_df["top_10"] = 0
# ALBUMS_df

# %%
FULL_df = TOP_df.append(ALBUMS_df, ignore_index=True)
# FULL_df

# %%
FULL_df.drop_duplicates(["song_id"], inplace=True)
FULL_df.reset_index(inplace=True, drop=True)
FULL_df
# Out:
#                      song_id                                     song_name  \
# 0     3y4LxiYMgDl4RethdzpmNe                                       Breathe
# 1     3i3GeK0qLQybu4ah42YmCY                     Smooth (feat. Rob Thomas)
# 2     3fucYASejkSMwtAYjFRKlF           Maria Maria (feat. The Product G&B)
# 3     6ctr1K7KzKErxbfGAynL8A                                  I Wanna Know
# 4     4cKGldbhGJniI8BrB3K6tb                           Everything You Want
# ...                      ...                                           ...
# 2299  6DPjPnAfdCO71OluEpmekE                              Damn Girl - Demo
# 2300  0QfnkUVZAr5l1SeqG2EydN                          Fallin' Apart - Demo
# 2301  1E4YUBtVN43cAN6uNHLaRA  Mona Lisa (When The World Comes Down) - Demo
# 2302  6l7yKJVwS5pzPGIdyG7kGZ                             Real World - Demo
# 2303  4sPmO7WMQUAf45kwMOtONw                                         Hello
#
#                    artist_id                    artist  explicit  popularity  \
# 0     25NQNriVT2YbSW80ILRWJa                Faith Hill     False          65
# 1     6GI52t8N5F02MxU0g5U69P                   Santana     False          54
# 2     6GI52t8N5F02MxU0g5U69P                   Santana     False          53
# 3     3zTOe1BtyTkwNvYZOxXktX                       Joe     False          57
# 4     6Hizgjo92FnMp8wGaRUNTn          Vertical Horizon     False          64
# ...                      ...                       ...       ...         ...
# 2299  3vAaWhdBR38Q02ohXqaNHT  The All-American Rejects     False          22
# 2300  3vAaWhdBR38Q02ohXqaNHT  The All-American Rejects     False          22
# 2301  3vAaWhdBR38Q02ohXqaNHT  The All-American Rejects     False          23
# 2302  3vAaWhdBR38Q02ohXqaNHT  The All-American Rejects     False          23
# 2303  4dpARuHxo51G3z768sgnrY                     Adele     False          71
#
#       danceability  energy  key  loudness  ...  valence    tempo  \
# 0            0.529   0.496    7    -9.007  ...    0.278  136.859
# 1            0.612   0.924    9    -3.877  ...    0.960  115.953
# 2            0.779   0.631    2    -5.314  ...    0.663   97.927
# 3            0.724   0.485    6    -5.919  ...    0.581  136.057
# 4            0.637   0.759    3    -6.389  ...    0.741   93.898
# ...            ...     ...  ...       ...  ...      ...      ...
# 2299         0.720   0.782   10    -6.069  ...    0.864  100.006
# 2300         0.806   0.602    0    -4.826  ...    0.850  126.013
# 2301         0.634   0.518    8    -8.454  ...    0.457  135.950
# 2302         0.452   0.897    0    -4.675  ...    0.532  159.880
# 2303         0.481   0.451    5    -6.095  ...    0.289  157.966
#
#                 type                      id  \
# 0     audio_features  3y4LxiYMgDl4RethdzpmNe
# 1     audio_features  3i3GeK0qLQybu4ah42YmCY
# 2     audio_features  3fucYASejkSMwtAYjFRKlF
# 3     audio_features  6ctr1K7KzKErxbfGAynL8A
# 4     audio_features  4cKGldbhGJniI8BrB3K6tb
# ...              ...                     ...
# 2299  audio_features  6DPjPnAfdCO71OluEpmekE
# 2300  audio_features  0QfnkUVZAr5l1SeqG2EydN
# 2301  audio_features  1E4YUBtVN43cAN6uNHLaRA
# 2302  audio_features  6l7yKJVwS5pzPGIdyG7kGZ
# 2303  audio_features  4sPmO7WMQUAf45kwMOtONw
#
#                                        uri  \
# 0     spotify:track:3y4LxiYMgDl4RethdzpmNe
# 1     spotify:track:3i3GeK0qLQybu4ah42YmCY
# 2     spotify:track:3fucYASejkSMwtAYjFRKlF
# 3     spotify:track:6ctr1K7KzKErxbfGAynL8A
# 4     spotify:track:4cKGldbhGJniI8BrB3K6tb
# ...                                    ...
# 2299  spotify:track:6DPjPnAfdCO71OluEpmekE
# 2300  spotify:track:0QfnkUVZAr5l1SeqG2EydN
# 2301  spotify:track:1E4YUBtVN43cAN6uNHLaRA
# 2302  spotify:track:6l7yKJVwS5pzPGIdyG7kGZ
# 2303  spotify:track:4sPmO7WMQUAf45kwMOtONw
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3y4LxiYMgDl4...
# 1     https://api.spotify.com/v1/tracks/3i3GeK0qLQyb...
# 2     https://api.spotify.com/v1/tracks/3fucYASejkSM...
# 3     https://api.spotify.com/v1/tracks/6ctr1K7KzKEr...
# 4     https://api.spotify.com/v1/tracks/4cKGldbhGJni...
# ...                                                 ...
# 2299  https://api.spotify.com/v1/tracks/6DPjPnAfdCO7...
# 2300  https://api.spotify.com/v1/tracks/0QfnkUVZAr5l...
# 2301  https://api.spotify.com/v1/tracks/1E4YUBtVN43c...
# 2302  https://api.spotify.com/v1/tracks/6l7yKJVwS5pz...
# 2303  https://api.spotify.com/v1/tracks/4sPmO7WMQUAf...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3y4L...      250547
# 1     https://api.spotify.com/v1/audio-analysis/3i3G...      295987
# 2     https://api.spotify.com/v1/audio-analysis/3fuc...      262160
# 3     https://api.spotify.com/v1/audio-analysis/6ctr...      296800
# 4     https://api.spotify.com/v1/audio-analysis/4cKG...      257067
# ...                                                 ...         ...
# 2299  https://api.spotify.com/v1/audio-analysis/6DPj...      216667
# 2300  https://api.spotify.com/v1/audio-analysis/0Qfn...      213613
# 2301  https://api.spotify.com/v1/audio-analysis/1E4Y...      163520
# 2302  https://api.spotify.com/v1/audio-analysis/6l7y...      235067
# 2303  https://api.spotify.com/v1/audio-analysis/4sPm...      295493
#
#      time_signature top_10
# 0                 4      1
# 1                 4      1
# 2                 4      1
# 3                 4      1
# 4                 4      1
# ...             ...    ...
# 2299              4      0
# 2300              4      0
# 2301              4      0
# 2302              4      0
# 2303              4      0
#
# [2304 rows x 25 columns]

# %%
FULL_df.columns
# Out:
# Index(['song_id', 'song_name', 'artist_id', 'artist', 'explicit', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'top_10'],
#       dtype='object')

# %%
#Set up data

# Assign X (data) and y (target)

# X = FULL_df.drop(['song_id', 'song_name', 'artist_id', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'top_10'], axis=1)
X = FULL_df.drop(['artist', 'song_id', 'song_name', 'artist_id', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'top_10'], axis=1)
# X = FULL_df.drop(['popularity', 'artist', 'song_id', 'song_name', 'artist_id', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'top_10'], axis=1)

y = FULL_df['top_10']
print(X.shape, y.shape)

#Split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# (2304, 15) (2304,)

# %% [markdown]
# ### Logistic Regression

# %%
#create model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(class_weight = 'balanced')

#train model
classifier.fit(X_train, y_train)

#test model
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}\n")

# Calculate classification report
target_names = ["negative", "positive"]
from sklearn.metrics import classification_report
predictions = classifier.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))

from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(classifier, X_test, y_test, cmap=plt.cm.Blues, display_labels=target_names)
plt.show()

# 
# feature_names = X.columns
# sorted(zip(classifier.feature_importances_, feature_names), reverse=True)
# # apparently logistic regression doesn't have feature importances..?
#
# Out:
# Training Data Score: 0.6851851851851852
# Testing Data Score: 0.6666666666666666
#
#               precision    recall  f1-score   support
#
#     negative       0.97      0.66      0.78       528
#     positive       0.17      0.79      0.28        48
#
#     accuracy                           0.67       576
#    macro avg       0.57      0.72      0.53       576
# weighted avg       0.91      0.67      0.74       576

# %% [markdown]
# ### Decision Tree

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(class_weight = 'balanced')

#train model
clf = clf.fit(X_train, y_train)

#test model
print(f"Training Data Score: {clf.score(X_train, y_train)}")
print(f"Testing Data Score: {clf.score(X_test, y_test)}\n")

predictions = clf.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))

plot_confusion_matrix(clf, X_test, y_test, cmap=plt.cm.Blues, display_labels=["average","top 10"])
plt.show()

feature_names = X.columns
sorted(zip(clf.feature_importances_, feature_names), reverse=True)
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8784722222222222
#
#               precision    recall  f1-score   support
#
#     negative       0.95      0.91      0.93       528
#     positive       0.34      0.48      0.40        48
#
#     accuracy                           0.88       576
#    macro avg       0.64      0.70      0.66       576
# weighted avg       0.90      0.88      0.89       576
# [(0.5283485233247904, 'popularity'),
#  (0.05987218644288015, 'acousticness'),
#  (0.05662542441990812, 'tempo'),
#  (0.05577099374409271, 'duration_ms'),
#  (0.05259706580119272, 'speechiness'),
#  (0.050505103053923514, 'danceability'),
#  (0.04604198302513008, 'loudness'),
#  (0.04119494186552577, 'liveness'),
#  (0.038951285699199, 'valence'),
#  (0.027287276606805126, 'energy'),
#  (0.018809680056124184, 'instrumentalness'),
#  (0.014633901757438911, 'key'),
#  (0.004541180254119777, 'mode'),
#  (0.002513962431319553, 'explicit'),
#  (0.0023064915175501927, 'time_signature')]

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200)

#train model
rf = rf.fit(X_train, y_train)

#test model
print(f"Training Data Score: {rf.score(X_train, y_train)}")
print(f"Testing Data Score: {rf.score(X_test, y_test)}\n")

predictions = rf.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))

plot_confusion_matrix(rf, X_test, y_test, cmap=plt.cm.Blues, display_labels=["average","top 10"])
plt.show()

feature_names = X.columns
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.9201388888888888
#
#               precision    recall  f1-score   support
#
#     negative       0.93      0.99      0.96       528
#     positive       0.56      0.19      0.28        48
#
#     accuracy                           0.92       576
#    macro avg       0.75      0.59      0.62       576
# weighted avg       0.90      0.92      0.90       576
# [(0.27970284929467304, 'popularity'),
#  (0.07948023129516711, 'danceability'),
#  (0.0769652743426412, 'valence'),
#  (0.07452377059054043, 'speechiness'),
#  (0.06985044157621813, 'duration_ms'),
#  (0.06747852272198132, 'loudness'),
#  (0.06488413415257062, 'acousticness'),
#  (0.06370456061789477, 'tempo'),
#  (0.06366195462675085, 'energy'),
#  (0.06033192590816892, 'liveness'),
#  (0.03822110190518949, 'key'),
#  (0.03509923936630742, 'instrumentalness'),
#  (0.011161667445779492, 'explicit'),
#  (0.0094181026529162, 'mode'),
#  (0.00551622350320117, 'time_signature')]

# %% [markdown]
# ### K Nearest Neighbors

# %%
# PART 1

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# Transform the training and testing data using the X_scaler and y_scaler models
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Loop through different k values to see which has the highest accuracy
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.884
# k: 3, Train/Test Score: 0.933/0.911
# k: 5, Train/Test Score: 0.927/0.917
# k: 7, Train/Test Score: 0.920/0.918
# k: 9, Train/Test Score: 0.918/0.918
# k: 11, Train/Test Score: 0.918/0.917
# k: 13, Train/Test Score: 0.917/0.915
# k: 15, Train/Test Score: 0.915/0.915
# k: 17, Train/Test Score: 0.913/0.915
# k: 19, Train/Test Score: 0.914/0.915

# %%
# PART 2

# Note that k: 7 seems to be the best choice for this dataset
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train_scaled, y_train)

#test model
print(f"Training Data Score: {knn.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {knn.score(X_test_scaled, y_test)}\n")

predictions = knn.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))

plot_confusion_matrix(knn, X_test, y_test, cmap=plt.cm.Blues, display_labels=["average","top 10"])
plt.show()

feature_names = X.columns
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# Training Data Score: 0.9201388888888888
# Testing Data Score: 0.9184027777777778
#
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96       528
#     positive       0.00      0.00      0.00        48
#
#     accuracy                           0.92       576
#    macro avg       0.46      0.50      0.48       576
# weighted avg       0.84      0.92      0.88       576
# [(0.27970284929467304, 'popularity'),
#  (0.07948023129516711, 'danceability'),
#  (0.0769652743426412, 'valence'),
#  (0.07452377059054043, 'speechiness'),
#  (0.06985044157621813, 'duration_ms'),
#  (0.06747852272198132, 'loudness'),
#  (0.06488413415257062, 'acousticness'),
#  (0.06370456061789477, 'tempo'),
#  (0.06366195462675085, 'energy'),
#  (0.06033192590816892, 'liveness'),
#  (0.03822110190518949, 'key'),
#  (0.03509923936630742, 'instrumentalness'),
#  (0.011161667445779492, 'explicit'),
#  (0.0094181026529162, 'mode'),
#  (0.00551622350320117, 'time_signature')]

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC 

model = SVC(kernel='linear', class_weight='balanced')

#train model
model.fit(X_train, y_train)

#test model
print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}\n")

# Calculate classification report
target_names = ["negative", "positive"]

predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))

plot_confusion_matrix(model, X_test, y_test, cmap=plt.cm.Blues, display_labels=["average","top 10"])
plt.show()

feature_names = X.columns
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# Training Data Score: 0.5329861111111112
# Testing Data Score: 0.515625
#
#               precision    recall  f1-score   support
#
#     negative       0.97      0.48      0.65       528
#     positive       0.13      0.85      0.23        48
#
#     accuracy                           0.52       576
#    macro avg       0.55      0.67      0.44       576
# weighted avg       0.90      0.52      0.61       576
# [(0.27970284929467304, 'popularity'),
#  (0.07948023129516711, 'danceability'),
#  (0.0769652743426412, 'valence'),
#  (0.07452377059054043, 'speechiness'),
#  (0.06985044157621813, 'duration_ms'),
#  (0.06747852272198132, 'loudness'),
#  (0.06488413415257062, 'acousticness'),
#  (0.06370456061789477, 'tempo'),
#  (0.06366195462675085, 'energy'),
#  (0.06033192590816892, 'liveness'),
#  (0.03822110190518949, 'key'),
#  (0.03509923936630742, 'instrumentalness'),
#  (0.011161667445779492, 'explicit'),
#  (0.0094181026529162, 'mode'),
#  (0.00551622350320117, 'time_signature')]

# %%
# #Gridsearch

# # Create the GridSearch estimator along with a parameter object containing the values to adjust
# from sklearn.model_selection import GridSearchCV
# param_grid = {'C': [1, 5, 10],
#               'gamma': [0.0001, 0.001, 0.01]}
# grid = GridSearchCV(model, param_grid, verbose=3)

# # Fit the model using the grid search estimator. 
# # This will take the SVC model and try each combination of parameters
# grid.fit(X_train, y_train)

# # List the best parameters for this dataset
# print(grid.best_params_)

# # List the best score
# print(grid.best_score_)

# # Make predictions with the hypertuned model
# predictions = grid.predict(X_test)

# # Calculate classification report
# from sklearn.metrics import classification_report
# print(classification_report(y_test, predictions,
#                             target_names=target_names))
